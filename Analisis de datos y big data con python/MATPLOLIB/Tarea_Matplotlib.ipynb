# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ###

# %% [markdown]
# ### BLOQUE 1 - Ejercicios iniciales

# %% [markdown]
# #### EJERCICIO 1

# %% [markdown]
# ##### Crea un gráfico de barras que compare las ventas trimestrales de tresproductos.
# ##### Incluye título, etiquetas y colores personalizados.

# %%
#VALORES PARA LA TABLA
Productos = ["Producto_1","Producto_2","Producto_3"]
Valores =[150,200,50]

#TIPO DE GRÁFICA, VALORES USADOS Y COLOR DE RELLENO
plt.bar(Productos, Valores, color='red')
#TITULO DEL GRAFICO
plt.title("Ventas trimestrales")
#MOSTRAR EL GRÁFICO
plt.show()

# %% [markdown]
# #### EJERCICIO 2

# %% [markdown]
# ##### Usando datos aleatorios, crea un histograma que muestre la distribución de edades de 200 personas.
# ##### Ajusta el número de bins para obtener una visualización clara.

# %%
datos=[(np.random.randint(3, 90,size=200))]
plt.hist(datos,bins=50,color='blue',edgecolor='black')
plt.title("Distribución de edades")
plt.xlabel("Edades")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# #### EJERCICIO 3

# %% [markdown]
# ##### Representa con un gráfico de líneas la evolución del precio medio de la gasolina durante 12 meses.
# ##### Añade una anotación donde se alcance el precio máximo.

# %%
precio = [12.30,
          10.50,
          50.10,
          5.60,
         15.45,
         7.12,
         8.15,
         6.15,
         20.50,
         80.20,
         90.00,
         75.89]
meses = ["Ene","Febr","Marz","Abr","May","Jun","Jul","Ago","Sept","Oct","Nov","Dic"]
plt.plot(meses,precio,color='green',linestyle='-')
plt.title("Media de precio anual")
plt.xlabel("Meses del año")
plt.ylabel("euros (€)")
plt.show()

# %% [markdown]
# #### EJERCICIO 4

# %% [markdown]
# ##### Combina varios subgráficos (subplots) en una figura con:
# ##### Un gráfico de barras,
# ##### Un gráfico de líneas
# ##### Un histograma
# ##### Analiza qué información aporta cada uno

# %%
fig, axs = plt.subplots(1,3, figsize=(15,4))

axs[0].bar(["Producto_1","Producto_2","Producto_3"], [150,200,50], color='orange')
axs[0].set_title("Barras")
axs[0].set_xlabel("Productos")
axs[0].set_ylabel("Valor €")


meses = ["Ene","Febr","Marz","Abr","May","Jun","Jul","Ago","Sept","Oct","Nov","Dic"]
precio = [12.30,10.50,50.10,5.60,15.45,7.12,8.15,6.15,20.50,80.20,90.00,75.89]

axs[1].plot(meses,precio,color='green',linestyle='-')
axs[1].set_title("Grafica Lineas")
axs[1].set_xlabel("Meses")
axs[1].set_ylabel("Valor €")

datos=[(np.random.randint(3, 90,size=200))]

axs[2].hist(datos,bins=50,color='blue',edgecolor='black')
axs[2].set_title("Distribución de edades")
axs[2].set_xlabel("Edades")
axs[2].set_ylabel("Frecuencia")


plt.show()

# %% [markdown]
# ##### El de barras aporta la diferencia de precio entre los diferentes productos que hay
# ##### El de líneas aporta la evolución del precio con respecto al tiempo en este caso cada mes
# ##### El de edades aporta la cantidad de veces aproximadamente que aparecen las edades que se encuentran dentro de los datos

# %% [markdown]
# ##

# %% [markdown]
# ### BLOQUE 2 - VISUALIZACIÓN DE RESULTADOS NUMPY

# %% [markdown]
# #### EJERCICIO 5 IMC (Ej.9-10 de la Tarea 1 / UD1):

# %%
#ELEMENTOS PARA LA VISUALIZACIÓN DE LOS EJERCICIOS
alturas = np.array([1.74, 1.8, 1.78, 1.68, 1.78, 1.7, 1.74, 1.74, 1.73,
1.79,
 1.78, 1.72, 1.65, 1.78, 1.7, 1.68, 1.79, 1.68, 1.82, 1.72,
 1.75, 1.66, 1.67, 1.79, 1.75, 1.65, 1.78, 1.73, 1.71, 1.81,
 1.73, 1.71, 1.68, 1.74, 1.75, 1.68, 1.74, 1.81, 1.73, 1.82,
 1.8, 1.67, 1.73, 1.7, 1.73, 1.7, 1.81, 1.81, 1.76, 1.82, 1.68,
 1.74, 1.65, 1.8, 1.78, 1.7, 1.68, 1.78, 1.79, 1.73, 1.64, 1.67,
 1.69, 1.74, 1.76, 1.66, 1.66, 1.73, 1.79, 1.81, 1.78, 1.63,
 1.76, 1.72, 1.71, 1.7, 1.62, 1.8, 1.75, 1.8, 1.78, 1.78, 1.76,
 1.65, 1.65, 1.68, 1.74, 1.75, 1.69, 1.75, 1.7, 1.83, 1.64, 1.7,
 1.69, 1.69, 1.64, 1.69, 1.77, 1.8, 1.78, 1.69, 1.7, 1.7, 1.7,
 1.63, 1.73, 1.84, 1.66, 1.78, 1.8, 1.79, 1.78, 1.74, 1.77,
 1.73, 1.77, 1.76, 1.75, 1.8, 1.75, 1.8, 1.79, 1.71, 1.73,
 1.59, 1.76, 1.75, 1.71, 1.76, 1.8, 1.68, 1.74, 1.77, 1.73,
 1.68, 1.63, 1.67])
pesos = np.array([81.4, 88.7, 87.3, 62.7, 81.6, 80.9, 74.6, 84.7, 76.7,
88.3,
 84.6, 74, 57.7, 84.1, 79.7, 63.8, 88.4, 71.2, 87.1, 67, 80.7,
 74.7, 60.5, 85.9, 72.4, 59.7, 87.3, 85.7, 64.1, 91.9, 82.8, 75.7,
 60.2, 73.1, 74.7, 65.9, 80.9, 91.3, 76, 86.8, 80.7, 74.2, 83.1,
 77.8, 84.5, 58.8, 89.5, 87, 84, 89.9, 56.5, 80.2, 61.8, 86.3,
 82.6, 69.4, 65.8, 79.3, 88.1, 78.5, 69.1, 62.5, 74, 74.4, 87.6,
 59.6, 61.4, 83.2, 89.2, 89.2, 103.7, 67.9, 85.4, 69.5, 75.7,
 83.9, 59.5, 87.9, 82.6, 88.1, 86.2, 88.9, 84.4, 58.4, 61.5, 69.2,
 84.2, 78, 81.1, 81.5, 74.7, 90.4, 59.2, 79.3, 65.1, 93, 60.5,
 76.4, 98.8, 89.1, 88.9, 61.1, 76.6, 86, 75.5, 66.9, 79.4, 87.9,
 72.3, 93.8, 89, 90.7, 86.7, 77.6, 85.1, 91.8, 103.2, 91.1, 67,
 86.9, 78.7, 87.1, 85.5, 69.8, 75, 53.9, 99, 93.7, 88, 79.4, 87.6,
 60.4, 82.7, 90.6, 79.8, 61.2, 62.5, 59.7])

alturasValor=alturas
alturas=alturas*alturas
imc=pesos/alturas

# %% [markdown]
# ##### Representa un histograma con la distribución de los valores IMC

# %%
plt.hist(imc,bins=20,color='orange',edgecolor='black')
plt.title("IMC")
plt.xlabel("IMC")
plt.ylabel("Frecuencia")
plt.axvline(18.5, color='gray', linestyle='--')
plt.text(19, 23, "PESO NORMAL", color='darkgreen')
plt.axvline(24.9, color='gray', linestyle='--')
plt.text(25, 30, "SOBREPESO", color='darkred')
plt.axvline(30, color='gray', linestyle='--')

# %% [markdown]
# ##### Añade líneas verticales que indiquen los rangos de peso normal, sobrepeso y obesidad

# %% [markdown]
# ##### Pregunta: ¿Qué tipo de gráfico representa mejor la distribución del IMC?
